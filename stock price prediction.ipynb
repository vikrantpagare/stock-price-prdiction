# %%
import pandas as pd

# %%
df = pd.read_csv("NIFTY 50-16-03-2023-to-16-03-2024.csv")

# %%
df.shape
# Out:
# (249, 7)

# %%
print(df.head())
# Out:
#          Date      Open      High       Low     Close   Shares Traded   \
# 0  16-MAR-2023  16994.65  17062.45  16850.15  16985.60       349820607
# 1  17-MAR-2023  17111.80  17145.80  16958.15  17100.05       408121255
# 2  20-MAR-2023  17066.60  17066.60  16828.35  16988.40       241777405
# 3  21-MAR-2023  17060.40  17127.70  17016.00  17107.50       246737873
# 4  22-MAR-2023  17177.45  17207.25  17107.85  17151.90       185700457
#
#    Turnover (₹ Cr)
# 0         24198.71
# 1         30478.42
# 2         21454.09
# 3         22039.11
# 4         15712.00

# %%
df.columns
# Out:
# Index(['Date ', 'Open ', 'High ', 'Low ', 'Close ', 'Shares Traded ',
#        'Turnover (₹ Cr)'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
df['High '].plot(kind='line')
df['Low '].plot(kind='line',color='red')
# Out:
# <AxesSubplot:>
